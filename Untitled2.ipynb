# %%
pip install scikit-learn matplotlib
# Out:
# Requirement already satisfied: scikit-learn in /home/vce/Newfolder/notebookenv/lib/python3.10/site-packages (1.6.1)
# Requirement already satisfied: matplotlib in /home/vce/Newfolder/notebookenv/lib/python3.10/site-packages (3.10.0)
# Requirement already satisfied: numpy>=1.19.5 in /home/vce/Newfolder/notebookenv/lib/python3.10/site-packages (from scikit-learn) (2.2.1)
# Requirement already satisfied: scipy>=1.6.0 in /home/vce/Newfolder/notebookenv/lib/python3.10/site-packages (from scikit-learn) (1.15.1)
# Requirement already satisfied: joblib>=1.2.0 in /home/vce/Newfolder/notebookenv/lib/python3.10/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/vce/Newfolder/notebookenv/lib/python3.10/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/vce/Newfolder/notebookenv/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/vce/Newfolder/notebookenv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/vce/Newfolder/notebookenv/lib/python3.10/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/vce/Newfolder/notebookenv/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/vce/Newfolder/notebookenv/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/vce/Newfolder/notebookenv/lib/python3.10/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/vce/Newfolder/notebookenv/lib/python3.10/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/vce/Newfolder/notebookenv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/vce/Newfolder/notebookenv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
data = pd.read_csv('diabetes(1).csv')
X = data.iloc[:, :-1].values  
y = data.iloc[:, -1].values   
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
print("Explained variance ratio:", pca.explained_variance_ratio_)
plt.figure(figsize=(8, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, cmap='viridis', edgecolor='k', s=100)
plt.title('PCA of Diabetes Dataset')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar()
plt.show()
# Out:
# Explained variance ratio: [0.88854663 0.06159078]
